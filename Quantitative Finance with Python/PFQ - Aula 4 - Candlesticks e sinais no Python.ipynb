# %% [markdown]
# ### Curso de Python para Finanças Quantitativas
#
# #### Aula 4 - Candlesticks e sinais no Python
# #### Autor: Leandro Guerra - Outspoken Market
# #### Download em: https://www.outspokenmarket.com/pythonfinancasquantitativas.html

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#!pip install mplfinance

# %%
# Carregando as bibliotecas necessarias
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import mplfinance as fplt
from pandas_datareader import data as pdr
from datetime import date
import yfinance as yf
yf.pdr_override()

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ___________________________________________

# %%
# Muda o diretorio de trabalho
import os
os.chdir("C:\\Users\\engle\\OM Na Pratica\\Finanças Quantitativas\\Bases de Dados")

# %% [markdown]
# ___________________________________________

# %% [markdown]
# ### Candlestick

# %%
# Parametros da funçao

ticker = "^BVSP"
inicio = "2015-01-01"
fim = "2021-05-31"

# %%
ibov = pdr.get_data_yahoo(ticker, start = inicio, end = fim)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Criando o seu gràfico

fplt.plot(
            ibov
            , type = "candle"
            , title = "Ibovespa - 2015/2021 - Outspoken Market"
            , ylabel = "Pontos"
        )

# %%
# Escolhendo apenas 2021

ibov2021 = ibov.loc["2021-01-1":"2021-12-31"]

# %%
# Gràfico de 2021

fplt.plot(
            ibov2021
            , type = "candle"
            , title = "Ibovespa 2021 - Outspoken Market"
            , ylabel = "Pontos"
        )

# %%
# Verificando a lista de estilos disponiveis

fplt.available_styles()
# Out:
# ['binance',
#  'blueskies',
#  'brasil',
#  'charles',
#  'checkers',
#  'classic',
#  'default',
#  'ibd',
#  'kenan',
#  'mike',
#  'nightclouds',
#  'sas',
#  'starsandstripes',
#  'yahoo']

# %%
# Gràfico com novo estilo

fplt.plot(
    ibov2021
    , type = "candle"
    , title = "Ibovespa 2021 - Outspoken Market"
    , ylabel = "Pontos"
    , style = "binance"
    , volume = True
)

# %%
# Adicionando o volume e finais de semana

fplt.plot(
    ibov2021
    , type = "candle"
    , title = "Ibovespa 2021 - Outspoken Market"
    , ylabel = "Pontos"
    , style = "charles"
    , volume = True
    , show_nontrading = True
)

# %%
# Adicionando uma média mòvel

fplt.plot(
    ibov2021
    , type = "candle"
    , title = "Ibovespa 2021 - Outspoken Market"
    , ylabel = "Pontos"
    , style = "charles"
    , volume = True
    , mav = 15
)

# %%
# Mudando o estilo geral

setup = fplt.make_mpf_style(mavcolors = ["yellow", "skyblue"]
                           , base_mpl_style = "fivethirtyeight")

fplt.plot(
    ibov2021
    , type = "candle"
    , title = "Ibovespa 2021 - Outspoken Market"
    , ylabel = "Pontos"
    , style = setup
    , mav = (5, 15)
    , figratio = (12,6)
)

# %% [markdown]
# ___________________________________________

# %% [markdown]
# ### Incluindo indicadores customizados e sinais

# %%
# Càlculo das BB

periodo = 20
desvios = 2
ibov["desvio"] = ibov["Adj Close"].rolling(periodo).std()
ibov["MM"] = ibov["Adj Close"].rolling(periodo).mean()
ibov["Banda_Sup"] = ibov["MM"] + (ibov["desvio"]*desvios)
ibov["Banda_Inf"] = ibov["MM"] - (ibov["desvio"]*desvios)

# %%
ibov2021 = ibov.loc["2021-01-1":"2021-12-31"]

# %%
# Criando o elemento das BB para adicional ao gràfico

bb = fplt.make_addplot(ibov2021[["MM", "Banda_Sup", "Banda_Inf"]])

# %%
# Gràfico com BB

fplt.plot(
    ibov2021
    , type = "candle"
    , title = "Ibovespa 2021 - Outspoken Market"
    , ylabel = "Pontos"
    , style = setup
    , figratio = (12,6)
    , addplot = bb
)

# %%
# Gera o sinal

ibov2021.loc[: , "Sinal_Inf"] = np.where((ibov2021.loc[: , "Close"] < ibov2021.loc[: , "Banda_Inf"] )
                                         , ibov2021.loc[: , "Close"]*0.99
                                         , np.nan)
ibov2021.loc[: , "Sinal_Sup"] = np.where((ibov2021.loc[: , "Close"] > ibov2021.loc[: , "Banda_Sup"] )
                                         , ibov2021.loc[: , "Close"]*1.01
                                         , np.nan)

# %%
ibov2021.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume  \
# Date
# 2021-01-04  119024.0  120354.0  118062.0  118558.0   118558.0   8741400
# 2021-01-05  118835.0  119790.0  116756.0  119223.0   119223.0   9257100
# 2021-01-06  119377.0  120924.0  118917.0  119851.0   119851.0  11638200
# 2021-01-07  119103.0  121983.0  119101.0  121956.0   121956.0  11774800
# 2021-01-08  122387.0  125324.0  122386.0  125077.0   125077.0  11085800
#
#                  desvio         MM      Banda_Sup      Banda_Inf  Sinal_Inf  \
# Date
# 2021-01-04  2416.051265  116008.15  120840.252529  111176.047471        NaN
# 2021-01-05  2304.554676  116378.60  120987.709351  111769.490649        NaN
# 2021-01-06  2277.978920  116725.20  121281.157839  112169.242161        NaN
# 2021-01-07  2441.654096  117138.90  122022.208193  112255.591807        NaN
# 2021-01-08  2878.050720  117711.50  123467.601440  111955.398560        NaN
#
#             Sinal_Sup
# Date
# 2021-01-04        NaN
# 2021-01-05        NaN
# 2021-01-06        NaN
# 2021-01-07        NaN
# 2021-01-08  126327.77

# %%
# Cria o vetor de indicadores

indicadores = [fplt.make_addplot(ibov2021["Sinal_Inf"], type = "scatter", markersize = 50, marker = "^", color = "green")
       , fplt.make_addplot(ibov2021["Sinal_Sup"], type = "scatter", markersize = 50, marker = "v", color = "red")
       , fplt.make_addplot(ibov2021[["MM", "Banda_Sup", "Banda_Inf"]], color = "darkblue")
      ]

# %%
# Adicionando os indicadores ao gràfico

fplt.plot(
    ibov2021
    , type = "candle"
    , title = "Ibovespa 2021 - Outspoken Market"
    , ylabel = "Pontos"
    , style = setup
    , figratio = (12,6)
    , addplot = indicadores
)

# %%
# Salva o gràfico em png

fplt.plot(
    ibov2021
    , type = "candle"
    , title = "Ibovespa 2021 - Outspoken Market"
    , ylabel = "Pontos"
    , style = setup
    , figratio = (12,6)
    , addplot = indicadores
    , savefig = "ibov2021.png"
)
